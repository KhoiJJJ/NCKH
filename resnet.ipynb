# %%
import os
import librosa
import numpy as np
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import classification_report
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, BatchNormalization, Activation, MaxPooling2D, Add, Flatten, Dense, GlobalAveragePooling2D
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.optimizers import Adam

# %%
# Hàm trích xuất MFCC
def extract_mfcc(audio, sr=16000, n_mfcc=40):
    hop_length = int(0.01 * sr)  # 10 ms hop
    win_length = int(0.025 * sr)  # 25 ms window
    mfcc = librosa.feature.mfcc(y=audio, sr=sr, n_mfcc=n_mfcc, hop_length=hop_length, win_length=win_length)
    return np.expand_dims(mfcc, axis=-1)  # Thêm chiều kênh (cho CNN/ResNet)

# Hàm tải dữ liệu
def load_data(data_dir):
    X = []
    y = []
    labels = os.listdir(data_dir)
    for label in labels:
        label_dir = os.path.join(data_dir, label)
        for file_name in os.listdir(label_dir):
            if file_name.endswith(".wav"):
                file_path = os.path.join(label_dir, file_name)
                # Tải tệp âm thanh
                audio, sr = librosa.load(file_path, sr=None)
                features = extract_mfcc(audio, sr)
                X.append(features)
                y.append(label)
    return np.array(X), np.array(y)

# %%
# Residual Block
def residual_block(x, filters, kernel_size=(3, 3), stride=(1, 1)):
    shortcut = x  # Đường tắt (identity connection)
    
    # Convolutional layer 1
    x = Conv2D(filters, kernel_size, strides=stride, padding="same")(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)
    
    # Convolutional layer 2
    x = Conv2D(filters, kernel_size, strides=(1, 1), padding="same")(x)
    x = BatchNormalization()(x)
    
    # Kết nối residual (shortcut connection)
    if shortcut.shape[-1] != filters:
        shortcut = Conv2D(filters, (1, 1), strides=stride, padding="same")(shortcut)
        shortcut = BatchNormalization()(shortcut)
    
    x = Add()([x, shortcut])
    x = Activation("relu")(x)
    return x

# %%
# Hàm xây dựng ResNet
def build_resnet(input_shape, num_classes):
    inputs = Input(shape=input_shape)
    
    # Initial convolutional layer
    x = Conv2D(64, (7, 7), strides=(2, 2), padding="same")(inputs)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)
    x = MaxPooling2D((3, 3), strides=(2, 2), padding="same")(x)
    
    # Residual blocks
    x = residual_block(x, 64)
    x = residual_block(x, 128, stride=(2, 2))  # Downsample
    x = residual_block(x, 256, stride=(2, 2))  # Downsample
    x = residual_block(x, 512, stride=(2, 2))  # Downsample
    
    # Global Average Pooling and Output layer
    x = GlobalAveragePooling2D()(x)
    outputs = Dense(num_classes, activation="softmax")(x)
    
    model = Model(inputs, outputs)
    model.compile(optimizer=Adam(learning_rate=0.001), loss="categorical_crossentropy", metrics=["accuracy"])
    return model

# %%
# Load dữ liệu
train_data_dir = r'C:\Users\USER\Downloads\SV_NCKH_audio_event\Train'
test_data_dir = r'C:\Users\USER\Downloads\SV_NCKH_audio_event\Test'

X_train, y_train = load_data(train_data_dir)
X_test, y_test = load_data(test_data_dir)

# Encode nhãn
le = LabelEncoder()
y_train = le.fit_transform(y_train)
y_test = le.transform(y_test)

# Chuẩn hóa dữ liệu và one-hot encode nhãn
num_classes = len(np.unique(y_train))
y_train = to_categorical(y_train, num_classes=num_classes)
y_test = to_categorical(y_test, num_classes=num_classes)

# Định dạng đầu vào (ResNet yêu cầu 4D tensor)
X_train = X_train.astype("float32")
X_test = X_test.astype("float32")

# %%
# Xây dựng ResNet
input_shape = X_train.shape[1:]
model = build_resnet(input_shape, num_classes)
model.summary()

# Huấn luyện mô hình
model.fit(X_train, y_train, batch_size=32, epochs=50, validation_data=(X_test, y_test))

# Đánh giá mô hình
test_loss, test_acc = model.evaluate(X_test, y_test)
print(f"Test accuracy: {test_acc:.4f}")

# Báo cáo kết quả
y_pred = np.argmax(model.predict(X_test), axis=1)
y_true = np.argmax(y_test, axis=1)
print("Classification Report:")
print(classification_report(y_true, y_pred, target_names=le.classes_))
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 40, 101,   │          0 │ -                 │
# │ (InputLayer)        │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 20, 51,    │      3,200 │ input_layer[0][0] │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 20, 51,    │        256 │ conv2d[0][0]      │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 20, 51,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 10, 26,    │          0 │ activation[0][0]  │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 10, 26,    │     36,928 │ max_pooling2d[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 10, 26,    │        256 │ conv2d_1[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1        │ (None, 10, 26,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 10, 26,    │     36,928 │ activation_1[0][… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 10, 26,    │        256 │ conv2d_2[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 10, 26,    │          0 │ batch_normalizat… │
# │                     │ 64)               │            │ max_pooling2d[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_2        │ (None, 10, 26,    │          0 │ add[0][0]         │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 5, 13,     │     73,856 │ activation_2[0][… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 5, 13,     │        512 │ conv2d_3[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_3        │ (None, 5, 13,     │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 5, 13,     │    147,584 │ activation_3[0][… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 5, 13,     │      8,320 │ activation_2[0][… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 5, 13,     │        512 │ conv2d_4[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 5, 13,     │        512 │ conv2d_5[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 5, 13,     │          0 │ batch_normalizat… │
# │                     │ 128)              │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_4        │ (None, 5, 13,     │          0 │ add_1[0][0]       │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 3, 7, 256) │    295,168 │ activation_4[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 3, 7, 256) │      1,024 │ conv2d_6[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_5        │ (None, 3, 7, 256) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 3, 7, 256) │    590,080 │ activation_5[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 3, 7, 256) │     33,024 │ activation_4[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 3, 7, 256) │      1,024 │ conv2d_7[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 3, 7, 256) │      1,024 │ conv2d_8[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 3, 7, 256) │          0 │ batch_normalizat… │
# │                     │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_6        │ (None, 3, 7, 256) │          0 │ add_2[0][0]       │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 2, 4, 512) │  1,180,160 │ activation_6[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 2, 4, 512) │      2,048 │ conv2d_9[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_7        │ (None, 2, 4, 512) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 2, 4, 512) │  2,359,808 │ activation_7[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 2, 4, 512) │    131,584 │ activation_6[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 2, 4, 512) │      2,048 │ conv2d_10[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 2, 4, 512) │      2,048 │ conv2d_11[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, 2, 4, 512) │          0 │ batch_normalizat… │
# │                     │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_8        │ (None, 2, 4, 512) │          0 │ add_3[0][0]       │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 512)       │          0 │ activation_8[0][… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 21)        │     10,773 │ global_average_p… │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 4,918,933 (18.76 MB)
#  Trainable params: 4,913,173 (18.74 MB)
#  Non-trainable params: 5,760 (22.50 KB)
# Epoch 1/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 49s 492ms/step - accuracy: 0.4942 - loss: 1.6982 - val_accuracy: 0.1454 - val_loss: 17.8322
# Epoch 2/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 43s 587ms/step - accuracy: 0.7368 - loss: 0.8322 - val_accuracy: 0.2291 - val_loss: 8.4755
# Epoch 3/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 42s 563ms/step - accuracy: 0.8037 - loss: 0.6027 - val_accuracy: 0.2263 - val_loss: 9.8997
# Epoch 4/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 58s 790ms/step - accuracy: 0.8386 - loss: 0.4838 - val_accuracy: 0.4088 - val_loss: 5.0600
# Epoch 5/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 69s 933ms/step - accuracy: 0.8507 - loss: 0.4546 - val_accuracy: 0.3059 - val_loss: 4.3028
# Epoch 6/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 49s 662ms/step - accuracy: 0.8521 - loss: 0.4454 - val_accuracy: 0.6269 - val_loss: 2.2627
# Epoch 7/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 47s 631ms/step - accuracy: 0.9033 - loss: 0.3162 - val_accuracy: 0.6036 - val_loss: 1.7479
# Epoch 8/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 48s 645ms/step - accuracy: 0.9119 - loss: 0.2630 - val_accuracy: 0.5720 - val_loss: 2.4070
# Epoch 9/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 57s 768ms/step - accuracy: 0.9206 - loss: 0.2464 - val_accuracy: 0.6214 - val_loss: 1.9724
# Epoch 10/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 53s 721ms/step - accuracy: 0.9360 - loss: 0.2055 - val_accuracy: 0.5789 - val_loss: 2.3460
# Epoch 11/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 59s 800ms/step - accuracy: 0.9397 - loss: 0.1766 - val_accuracy: 0.5350 - val_loss: 2.5552
# Epoch 12/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 53s 706ms/step - accuracy: 0.9434 - loss: 0.1744 - val_accuracy: 0.5912 - val_loss: 2.0603
# Epoch 13/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 83s 726ms/step - accuracy: 0.9462 - loss: 0.1547 - val_accuracy: 0.5679 - val_loss: 2.7213
# Epoch 14/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 39s 525ms/step - accuracy: 0.9534 - loss: 0.1411 - val_accuracy: 0.5432 - val_loss: 2.7640
# Epoch 15/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 38s 507ms/step - accuracy: 0.9680 - loss: 0.1076 - val_accuracy: 0.5995 - val_loss: 2.0289
# Epoch 16/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 38s 515ms/step - accuracy: 0.9657 - loss: 0.1038 - val_accuracy: 0.6351 - val_loss: 2.1754
# Epoch 17/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 38s 513ms/step - accuracy: 0.9693 - loss: 0.0844 - val_accuracy: 0.6159 - val_loss: 2.0847
# Epoch 18/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 41s 548ms/step - accuracy: 0.9697 - loss: 0.0852 - val_accuracy: 0.6475 - val_loss: 2.5602
# Epoch 19/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 38s 510ms/step - accuracy: 0.9600 - loss: 0.1357 - val_accuracy: 0.5926 - val_loss: 2.7454
# Epoch 20/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 34s 466ms/step - accuracy: 0.9558 - loss: 0.1333 - val_accuracy: 0.5912 - val_loss: 3.0235
# Epoch 21/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 48s 650ms/step - accuracy: 0.9715 - loss: 0.0927 - val_accuracy: 0.5748 - val_loss: 2.4630
# Epoch 22/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 38s 504ms/step - accuracy: 0.9745 - loss: 0.0902 - val_accuracy: 0.5830 - val_loss: 2.1754
# Epoch 23/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 33s 448ms/step - accuracy: 0.9823 - loss: 0.0540 - val_accuracy: 0.6406 - val_loss: 2.1982
# Epoch 24/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 33s 447ms/step - accuracy: 0.9879 - loss: 0.0331 - val_accuracy: 0.6200 - val_loss: 2.1778
# Epoch 25/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 36s 485ms/step - accuracy: 0.9978 - loss: 0.0114 - val_accuracy: 0.6036 - val_loss: 2.3367
# Epoch 26/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 35s 478ms/step - accuracy: 0.9973 - loss: 0.0125 - val_accuracy: 0.5761 - val_loss: 2.6601
# Epoch 27/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 36s 485ms/step - accuracy: 0.9935 - loss: 0.0212 - val_accuracy: 0.6104 - val_loss: 2.4843
# Epoch 28/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 35s 468ms/step - accuracy: 0.9927 - loss: 0.0330 - val_accuracy: 0.6022 - val_loss: 2.4278
# Epoch 29/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 36s 491ms/step - accuracy: 0.9781 - loss: 0.0652 - val_accuracy: 0.5871 - val_loss: 3.3978
# Epoch 30/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 35s 469ms/step - accuracy: 0.9604 - loss: 0.1305 - val_accuracy: 0.5734 - val_loss: 3.0264
# Epoch 31/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 36s 485ms/step - accuracy: 0.9853 - loss: 0.0514 - val_accuracy: 0.5816 - val_loss: 3.2404
# Epoch 32/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 39s 534ms/step - accuracy: 0.9946 - loss: 0.0238 - val_accuracy: 0.5775 - val_loss: 3.5243
# Epoch 33/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 38s 506ms/step - accuracy: 0.9933 - loss: 0.0254 - val_accuracy: 0.6228 - val_loss: 2.3198
# Epoch 34/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 36s 490ms/step - accuracy: 0.9936 - loss: 0.0289 - val_accuracy: 0.6036 - val_loss: 2.9748
# Epoch 35/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 38s 517ms/step - accuracy: 0.9858 - loss: 0.0442 - val_accuracy: 0.6283 - val_loss: 2.6763
# Epoch 36/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 38s 506ms/step - accuracy: 0.9806 - loss: 0.0519 - val_accuracy: 0.6214 - val_loss: 2.7685
# Epoch 37/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 36s 492ms/step - accuracy: 0.9903 - loss: 0.0295 - val_accuracy: 0.5665 - val_loss: 3.0485
# Epoch 38/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 42s 567ms/step - accuracy: 0.9907 - loss: 0.0312 - val_accuracy: 0.6077 - val_loss: 2.7698
# Epoch 39/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 35s 479ms/step - accuracy: 0.9686 - loss: 0.1011 - val_accuracy: 0.6063 - val_loss: 2.8595
# Epoch 40/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 41s 559ms/step - accuracy: 0.9735 - loss: 0.0787 - val_accuracy: 0.6049 - val_loss: 2.3888
# Epoch 41/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 41s 552ms/step - accuracy: 0.9883 - loss: 0.0413 - val_accuracy: 0.6406 - val_loss: 2.4969
# Epoch 42/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 37s 495ms/step - accuracy: 0.9938 - loss: 0.0185 - val_accuracy: 0.6118 - val_loss: 2.6164
# Epoch 43/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 36s 483ms/step - accuracy: 0.9916 - loss: 0.0198 - val_accuracy: 0.6145 - val_loss: 2.7361
# Epoch 44/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 36s 488ms/step - accuracy: 0.9912 - loss: 0.0187 - val_accuracy: 0.6200 - val_loss: 2.6492
# Epoch 45/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 35s 470ms/step - accuracy: 0.9927 - loss: 0.0299 - val_accuracy: 0.6022 - val_loss: 2.9968
# Epoch 46/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 35s 476ms/step - accuracy: 0.9795 - loss: 0.0603 - val_accuracy: 0.6049 - val_loss: 2.9822
# Epoch 47/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 70s 958ms/step - accuracy: 0.9952 - loss: 0.0156 - val_accuracy: 0.6488 - val_loss: 2.4555
# Epoch 48/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 43s 577ms/step - accuracy: 0.9985 - loss: 0.0084 - val_accuracy: 0.6228 - val_loss: 2.5969
# Epoch 49/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 43s 586ms/step - accuracy: 0.9996 - loss: 0.0042 - val_accuracy: 0.6241 - val_loss: 2.3574
# Epoch 50/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 45s 601ms/step - accuracy: 0.9996 - loss: 0.0017 - val_accuracy: 0.6310 - val_loss: 2.6667
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 131ms/step - accuracy: 0.4479 - loss: 4.3452
# Test accuracy: 0.6310
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 153ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#       Sound0       0.12      0.03      0.05        67
#       Sound1       0.55      0.14      0.22        44
#      Sound10       0.79      0.88      0.83        64
#      Sound11       0.49      0.53      0.51        47
#      Sound12       0.80      0.29      0.42        14
#      Sound13       1.00      1.00      1.00        51
#      Sound14       0.44      1.00      0.61        30
#      Sound15       1.00      1.00      1.00         2
#      Sound16       0.23      0.12      0.16        66
#      Sound17       0.67      0.67      0.67        64
#      Sound18       0.00      0.00      0.00         8
#      Sound19       0.32      0.52      0.39        23
#       Sound2       0.98      1.00      0.99        55
#      Sound20       0.52      0.93      0.67        46
#       Sound3       1.00      1.00      1.00        15
#       Sound4       0.72      0.97      0.83        88
#       Sound5       0.29      0.40      0.33         5
#       Sound6       0.00      0.00      0.00         6
#       Sound7       0.70      0.70      0.70        23
#       Sound8       0.50      0.83      0.62         6
#       Sound9       0.00      0.00      0.00         5
#
#     accuracy                           0.63       729
#    macro avg       0.53      0.57      0.52       729
# weighted avg       0.58      0.63      0.58       729
# C:\Users\USER\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\USER\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\USER\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
